# %% [markdown]
# <a href="https://colab.research.google.com/github/DunjaPawlovic/data-analysis-course/blob/main/notebook/01_load_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/DunjaPawlovic/data-analysis-course/main/data/deezer_top_20_2025-06-01.csv"

df = pd.read_csv(url)

df.head()
